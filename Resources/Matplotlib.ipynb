# %% [markdown]
# ## Matplotlib
#
# Matplotlib is a python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms. matplotlib can be used in python scripts, the python and ipython shell (ala MATLAB®* or Mathematica®†), web application servers, and six graphical user interface toolkits. RTD [here](http://matplotlib.org/)! Forked and modded off https://github.com/stefsy/matplotlib-charts/.

# %% [markdown]
# ### Basic Plotting

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,25)
y = np.arange(0,25)

# %%
plt.style.use('fivethirtyeight')
plt.plot(x,y)

# %% [markdown]
# ### Customizing and Styling the Chart
#
# The `plt` object can be used to specify labels and add new series to the plot. See below:

# %%
x = np.arange(0,30)
a = np.arange(10,40)
b = [b**2 for b in range(0,30)]
c = [100 for c in range(0,30)]

plt.title("Some Functions")
plt.plot(x,a, label='linear')
plt.plot(x,b, label='exponential')
plt.plot(x,c, label='flat')
plt.legend(loc='upper left', frameon=True)
plt.ylabel('The Y Label')
plt.xlabel('The X Label')

# %% [markdown]
# ### Scatterplots
#
# We can use scatterplots to present clusters of data. Call `plt.scatter` and the x and y coordinate pairs to create a scatter plot.

# %%
n = 100
ax = np.random.randn(n)
ay = np.random.randn(n)

plt.scatter(ax, ay)

# %% [markdown]
# **Colors**: One can specify the color palette for Matplotlib. This one uses the Tableau color way scaled to the Matplotlib format.

# %%
# These are the "Tableau 20" colors as RGB.  
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]

# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
for i in range(len(tableau20)):  
    r, g, b = tableau20[i]  
    tableau20[i] = (r / 255., g / 255., b / 255.)

# %%
# c for color, alpha for transparency
plt.scatter(ax, ay, c=tableau20[4], alpha=0.85)

# %% [markdown]
# #### Multiple Scatter plots

# %%
plt.scatter(np.random.randn(300), np.random.randn(300), c=tableau20[4], alpha=0.75, label="green")
plt.scatter(np.random.randn(200), np.random.randn(200), c=tableau20[2], alpha=0.5, label="orange")
plt.scatter(np.random.randn(100), np.random.randn(100), c=tableau20[6], alpha=0.5, label="red")
plt.legend(loc='upper left', frameon=True)

# %% [markdown]
# #### Enlarge the plot area

# %%
# set the figsize first. The figure is the canvas. Takes a tuple whose value is width, height in inches.

plt.figure(figsize=(10,8))
plt.scatter(ax, ay, c=tableau20, alpha=0.95)

# %% [markdown]
# ### Subplots

# %%
# this sets the figure on which we'll draw all the subplots
plt.figure(figsize=(10,8))

# data
x1 = np.arange(1,10)
y1 = [10 for y in range(1,10)]
x2 = np.arange(1,10)
y2 = np.arange(1,10)


# subplot(number_of_rows, number_of_columns, which_plot_is_this)
# which_plot_is_this starts at ONE, not at zero.
# This is terribly unpythonic because it's a Matlab convension.plt.subplot(2, 1, 1)
plt.subplot(2, 1, 1)
plt.plot(x1, y1, c=tableau20[10])
plt.title('My First Multi-plot')
plt.ylabel('First Plot')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, c=tableau20[5])
plt.xlabel('time (s)')
plt.ylabel('Second Plot')

# %%
# this sets the figure on which we'll draw all the subplots
plt.figure(figsize=(10,8))

# data
x = np.arange(1,10)
y1 = [10 for y in range(1,10)]
y2 = np.arange(1,10)

# first subplot
plt.subplot(2, 2, 1)
plt.plot(x, y1, c=tableau20[19])
plt.title('Multiple Plots')
plt.ylabel('First Plot')

# second subplot
plt.subplot(2, 2, 2)
plt.scatter(np.random.randn(200), np.random.randn(200), c=tableau20[5], alpha=0.9, label="orange")
plt.ylabel('Second Plot')

# third subplot
plt.subplot(2, 2, 3)
plt.scatter(np.random.randn(200), np.random.randn(200), c=tableau20[13], alpha=0.9, label="orange")
plt.ylabel('Third Plot')

# fourth subplot
plt.subplot(2, 2, 4)
plt.plot(x, y2, c=tableau20[8])
plt.ylabel('Fourth  Plot')

# %% [markdown]
# ### Pandas and Matplotlib

# %%
import pandas as pd 

plt.figure(figsize=(12,8))


ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()

ts2 = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts2 = ts.cumsum()

ts2.plot(title="Sample Time Series", kind='kde', c=tableau20[8])

# %%
ts2
# Out:
# 2000-01-01       -0.054959
# 2000-01-02       -0.136159
# 2000-01-03        2.110254
# 2000-01-04        4.348707
# 2000-01-05        5.637837
# 2000-01-06        4.993193
# 2000-01-07        4.367532
# 2000-01-08        4.240731
# 2000-01-09        4.942359
# 2000-01-10        6.634609
# 2000-01-11        7.252313
# 2000-01-12        9.367529
# 2000-01-13       13.086746
# 2000-01-14       17.011695
# 2000-01-15       20.544542
# 2000-01-16       23.666022
# 2000-01-17       25.408652
# 2000-01-18       27.375258
# 2000-01-19       29.930594
# 2000-01-20       33.935758
# 2000-01-21       37.900220
# 2000-01-22       43.565140
# 2000-01-23       48.673714
# 2000-01-24       53.417372
# 2000-01-25       58.275085
# 2000-01-26       62.973875
# 2000-01-27       67.515979
# 2000-01-28       72.166795
# 2000-01-29       75.544513
# 2000-01-30       78.508593
#                   ...
# 2002-08-28    19803.222144
# 2002-08-29    19816.758949
# 2002-08-30    19829.234456
# ...
