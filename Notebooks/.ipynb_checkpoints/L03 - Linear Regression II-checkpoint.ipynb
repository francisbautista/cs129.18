# %%
# %matplotlib inline

import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/nscb_electric_energy_consumption_by_sector_1993-2011.CSV")

# %%
df.head()
# Out:
#    year  total  residential  commercial  industrial  transport  others  \
# 0  1993  26579         6368        4725        9395          0     721
# 1  1994  30459         7282        5865       10684          0     762
# 2  1995  33554         8223        6353       10950          0    1067
# 3  1996  36708         9150        7072       11851         27    1140
# 4  1997  39767        10477        7984       12531         29    1239
#
#    utilities_or_own_use  power_losses
# 0                  1132          4238
# 1                  1132          4734
# 2                  1226          5735
# 3                  1340          6128
# 4                  1471          6037

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,8))

plt.scatter(df["year"], df["industrial"])
plt.xlabel("Mean number of rooms per house")
plt.ylabel("House Price")
plt.title("Relationship between Room Count Price")
# Out:
# Text(0.5,1,'Relationship between Room Count Price')
